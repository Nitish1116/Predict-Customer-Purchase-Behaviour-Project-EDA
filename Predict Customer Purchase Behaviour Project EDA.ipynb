# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/Users/nitishkumar/Downloads/Data_sets/customer_purchase_data.csv")

# %%
data
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
data.tail()
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 1495           34.590743               0                 5               1
# 1496           17.625707               0                 1               1
# 1497           12.206033               0                 0               0
# 1498           37.311634               1                 0               1
# 1499           25.348017               1                 4               1

# %%
#No. of rows and columns 
data.shape
# Out:
# (1500, 9)

# %%
data.shape[0]
# Out:
# 1500

# %%
data.shape[1]
# Out:
# 9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1500 non-null   int64
#  1   Gender              1500 non-null   int64
#  2   AnnualIncome        1500 non-null   float64
#  3   NumberOfPurchases   1500 non-null   int64
#  4   ProductCategory     1500 non-null   int64
#  5   TimeSpentOnWebsite  1500 non-null   float64
#  6   LoyaltyProgram      1500 non-null   int64
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 105.6 KB

# %%
data.describe()
# Out:
#                Age       Gender   AnnualIncome  NumberOfPurchases  \
# count  1500.000000  1500.000000    1500.000000        1500.000000
# mean     44.298667     0.504667   84249.164338          10.420000
# std      15.537259     0.500145   37629.493078           5.887391
# min      18.000000     0.000000   20001.512518           0.000000
# 25%      31.000000     0.000000   53028.979155           5.000000
# 50%      45.000000     1.000000   83699.581476          11.000000
# 75%      57.000000     1.000000  117167.772858          15.000000
# max      70.000000     1.000000  149785.176481          20.000000
#
#        ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  \
# count      1500.000000         1500.000000     1500.000000       1500.000000
# mean          2.012667           30.469040        0.326667          2.555333
# std           1.428005           16.984392        0.469151          1.705152
# ...

# %%
#to find null values
data.isnull().sum()
# Out:
# Age                   0
# Gender                0
# AnnualIncome          0
# NumberOfPurchases     0
# ProductCategory       0
# TimeSpentOnWebsite    0
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
data.isnull().head(10)
# Out:
#      Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0  False   False         False              False            False
# 1  False   False         False              False            False
# 2  False   False         False              False            False
# 3  False   False         False              False            False
# 4  False   False         False              False            False
# 5  False   False         False              False            False
# 6  False   False         False              False            False
# 7  False   False         False              False            False
# 8  False   False         False              False            False
# 9  False   False         False              False            False
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0               False           False             False           False
# 1               False           False             False           False
# ...

# %%
#only columns
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
# only specific row
data[data.index == 5]
# Out:
#    Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 5   66       1  37758.117475                 14                4
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 5           17.827493               0                 2               0

# %%
#Isolating two or more rows using [ ] 
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
data[data.index.isin(range(2,15))]
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 2    27       1  127821.306432                 11                2
# 3    24       1  137798.623120                 19                3
# 4    31       1   99300.964220                 19                1
# 5    66       1   37758.117475                 14                4
# 6    39       1  126883.385286                 16                3
# 7    64       1   39707.359724                 13                2
# 8    43       0  102797.301269                 20                1
# 9    20       1   63854.921080                 16                0
# 10   66       1   66199.993929                 11                1
# 11   70       1   83556.718133                 11                2
# 12   54       0  114467.228969                  9                2
# 13   64       1   31880.893223                 17                0
# 14   19       1  107485.660911                  7                1
#
# ...

# %%
data.loc[2:10]
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 2    27       1  127821.306432                 11                2
# 3    24       1  137798.623120                 19                3
# 4    31       1   99300.964220                 19                1
# 5    66       1   37758.117475                 14                4
# 6    39       1  126883.385286                 16                3
# 7    64       1   39707.359724                 13                2
# 8    43       0  102797.301269                 20                1
# 9    20       1   63854.921080                 16                0
# 10   66       1   66199.993929                 11                1
#
#     TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 2            31.633212               1                 0               1
# 3            46.167059               0                 4               1
# 4            19.823592               0                 0               1
# ...

# %%
# top 5 TimeSpentOnWebsite
data.nlargest(5,'TimeSpentOnWebsite')
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 616    29       1   58153.547017                 16                2
# 209    42       0   42778.830374                 17                3
# 689    18       1   87934.957914                  6                0
# 1394   45       0  149200.290557                  7                3
# 172    53       1   21575.700704                 10                4
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 616            59.991105               1                 3               1
# 209            59.985342               0                 3               0
# 689            59.968606               1                 4               1
# 1394           59.960841               0                 1               0
# 172            59.900807               0                 1               0

# %%
# least 5 TimeSpentOnWebsite
data.nsmallest(5,'TimeSpentOnWebsite')
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 20     59       0   92768.238873                  3                2
# 1309   42       0   54021.738886                 18                3
# 806    34       0  133648.928209                  4                3
# 1440   69       0  116017.669557                  9                4
# 201    66       1  141127.983526                  0                1
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 20              1.037023               0                 5               0
# 1309            1.044115               1                 2               0
# 806             1.074817               0                 2               0
# 1440            1.094470               0                 2               0
# 201             1.128864               0                 3               0

# %%
# top 5 NumberOfPurchases
data.nlargest(5,'NumberOfPurchases')
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 8    43       0  102797.301269                 20                1
# 44   50       1   57327.934551                 20                1
# 74   43       1   66806.560567                 20                4
# 80   22       1   86465.810086                 20                2
# 81   40       0   98472.836073                 20                0
#
#     TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 8             6.023475               0                 3               0
# 44           30.655177               1                 3               1
# 74           55.592003               1                 0               1
# 80           53.631473               0                 3               1
# 81           53.051870               0                 2               0

# %%
# least 5 NumberOfPurchases
data.nsmallest(5,'NumberOfPurchases')
# Out:
#      Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 17    18       1  128374.495052                  0                2
# 62    52       1  116034.009594                  0                4
# 110   62       1   93492.933094                  0                0
# 144   25       0   72231.244085                  0                2
# 160   40       0  136232.259329                  0                4
#
#      TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 17            16.768262               0                 4               0
# 62            21.420402               1                 3               1
# 110           26.360836               0                 3               0
# 144           16.826771               1                 3               1
# 160            4.728108               0                 3               0

# %%
data['ProductCategory'].value_counts()
# Out:
# ProductCategory
# 1    331
# 4    321
# 0    289
# 3    286
# 2    273
# Name: count, dtype: int64

# %%
data['DiscountsAvailed'].value_counts()
# Out:
# DiscountsAvailed
# 3    265
# 5    258
# 4    258
# 1    242
# 0    240
# 2    237
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
#Annual Income vs Number of Purchases
sns.set(style="whitegrid")
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='AnnualIncome', y='NumberOfPurchases', hue='PurchaseStatus', palette='viridis')
plt.title('Annual Income vs Number of Purchases')
plt.xlabel('Annual Income')
plt.ylabel('Number of Purchases')
plt.legend(title='Purchase Status')
plt.show()

# %%
#Time Spent on Website by Purchase Status
plt.figure(figsize=(8,6))
sns.boxplot(data,x='PurchaseStatus', y='TimeSpentOnWebsite',hue='PurchaseStatus', palette='Set2')
plt.title('Time Spent on Website by Purchase Status')
plt.xlabel('Purchase Status (0: No, 1: Yes)')
plt.ylabel('Time Spent on Website (minutes)')
plt.show()

# %%
#Loyalty Program Members vs Purchase Status
plt.figure(figsize=(8,6))
sns.countplot(data,x='LoyaltyProgram', hue='PurchaseStatus', palette='pastel')
plt.title('Loyalty Program Members vs Purchase Status')
plt.xlabel('Loyalty Program (0: No, 1: Yes)')
plt.ylabel('Count')
plt.legend(title='Purchase Status')
plt.show()

# %%
#Heatmap of Correlation Matrix
plt.figure(figsize=(10,8))
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#Purchase Status vs Age
plt.figure(figsize=(10, 6))
sns.boxplot(data,x='PurchaseStatus', y='Age',)
plt.title("Age Distribution by Purchase Status")
plt.show()

# %%
#Purchase Status vs Income
plt.figure(figsize=(10, 6))
sns.lineplot(data,x='PurchaseStatus', y='AnnualIncome')
plt.title("Annual Income by Purchase Status")
plt.show()

# %%
#Discounts Availed and Purchases
plt.figure(figsize=(10, 6))
sns.boxplot(data,x='PurchaseStatus', y='DiscountsAvailed')
plt.title("Discounts Availed by Purchase Status")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data,x='LoyaltyProgram', y='DiscountsAvailed')
plt.title("Discounts Availed by Loyalty Program")
plt.show()

# %%
#  Product Category Preferences
plt.figure(figsize=(10, 6))
sns.countplot(x='ProductCategory', hue='PurchaseStatus', data=df)
plt.title("Product Category Preferences by Purchase Status")
plt.show()

# %%
#Time Spent on Website vs Purchases
plt.figure(figsize=(10, 6))
sns.boxplot(x='PurchaseStatus', y='TimeSpentOnWebsite', data=df)
plt.title("Time Spent on Website by Purchase Status")
plt.show()

# %%
data.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['AnnualIncome'], bins=20, edgecolor='black')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.title('Distribution of Annual Income')
plt.show()

# %%
avg_purchases = data.groupby('ProductCategory')['NumberOfPurchases'].mean().sort_values()
plt.figure(figsize=(12, 8))
avg_purchases.plot(kind='bar', color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Average Number of Purchases')
plt.title('Average Number of Purchases by Product Category')
plt.xticks(rotation=45)
plt.show()

# %%
status_counts = data['PurchaseStatus'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Purchase Status')
plt.show()

# %%
sns.boxplot(x="Gender", y="NumberOfPurchases", data=data)

plt.xlabel("Gender")
plt.ylabel("Number of Purchases")
plt.title("Number of Purchases by Gender")
plt.show()

# %%
sns.violinplot(x="ProductCategory", y="NumberOfPurchases", data=data)
plt.xlabel("Product Category")
plt.ylabel("Number of Purchases")
plt.title("Purchase Distribution by Product Category")
plt.show()

# %%
sns.pairplot(data.select_dtypes(include=['number']))
plt.show()
